# %% [markdown]
# import tkinter as tk from tkinter import \* from PIL import Image,
# ImageTk
#
# window_main=tk.Tk(className=“Baby Name Generator”)
# window_main.geometry(‘600x600’)
#
# namelistdb=\[“Arjun”,“Ananya”,“Aishwarya”,“Ajit”,“Bajaj”,“Barney”,“Banu”,“Begam”,“Catherine”,“Casandra”,
# “Chandler”,“Clara”,“Danush”,“Dinesh”,“Disha”,“Danny”,“Erikson”,“Emily”,“Erica”,“Evan”,“Frank”,“Fedrick”,
# “Farah”,“Flora”,“George”,“Gabriel”,“Georgiana”,“Grandy”,“Hoseok”,“Harris”,“Helen”,“Heidy”,“Isabella”,
# “Imanuel”,“Isla”,“Ishan”,“Joey”,“Jimin”,“Jin”,“Jeonguk”,“Kyle”,“Kiara”,“Krish”,“Kunal”,“Luka”,
# “Lisa”,“Lidiya”,“Leo”,“Marshal”,“Monica”,“Mathew”,“Melisa”,“Nova”,“Namjoon”,“Natasha”,“Natalie”,
# “Olivia”,“Oscar”,“Oviya”,“Olive”,“Pooja”,“Priya”,“Phoebe”,“Preethi”,“Quinton”,“Quincy”,“Quasim”,
# “Quest”,“Rachael”,“Ross”,“Rudy”,“Robin”,“Suga”,“Sakshi”,“Sam”,“Sonakshi”,“Taehyung”,“Ted”,“Thomas”,
# “Thiya”,“Umar”,“Uriel”,“Uziel”,“Udhaya”,“Vincenzo”,“Victoria”,“Vijay”,“Vikram”,“Will”,“Walter”,“Wendy”,
# “Winnie”,“Xyla”,“Xavier”,“Xian”,“Xia”,“Yoongi”,“Yeontan”,“Yuvi”,“Yamini”,“Zara”,“Zayn”,“Zeke”,“Zendaya”\]
#
# img=ImageTk.PhotoImage(Image.open(“C:\\Users\\Lenovo\\OneDrive\\Pictures\\bear
# wallpaper pc Mac 네이버 아이콘 곰.png”)) l=Label(image=img) l.pack()
#
# app_label=tk.Label(window_main, text=“BABY NAME GENERATOR”,
# font=(‘Arial’ ,20,‘bold’), foreground=“white”, background=“brown”)
# app_label.place(x=130 , y=20)
#
# name_label=tk.Label(window_main,text=“Please enter the Letter”,
# font=(‘Walbaum text’,12)) name_label.place(x=50, y=100)
#
# a_var=tk.StringVar() alphabel_entry=tk.Entry(window_main,
# font=(‘Arial’,20,‘italic’), textvariable=a_var).place(x=250,y=100)
#
# def displaynamesfunc(): for i in namelistdb: if
# i\[0\]\[0\].lower()==a_var.get().lower(): textarea.insert(END,(i+" "))
#
# display_button=tk.Button(window_main, font=(‘Walbaum text’,18,‘bold’),
# foreground=“white”, background=“brown” ,text=“Generate Names”,
# command=displaynamesfunc)
# display_button.place(x=200, y=300)
#
# textarea_var=tk.StringVar() textarea=tk.Text(window_main,
# font=(‘calibri’,12)) textarea.place(x=30, y=340, width=440, height=120)
#
# def clearfunc(): a_var.set("“) textarea.delete(”1.0“,”end")
#
# def exitfunc(): window_main.destroy()
#
# clear_button=tk.Button(window_main, font=(‘Arial’,10,‘bold’),
# foreground=“white”, background=“green”, text=“Clear”, command=clearfunc)
# clear_button.place(x=400, y=520)
#
# exit_button=tk.Button(window_main, font=(‘Arial’,10,‘bold’),
# foreground=“white”, background=“red” , text=“Exit”, command=exitfunc)
# exit_button.place(x=470, y=520)
#
# window_main.mainloop()
